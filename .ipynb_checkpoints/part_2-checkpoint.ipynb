# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [15, 9]

df2 = pd.read_csv('data/crypto.csv')

bit = df2[df2['Asset_Name'] == 'Bitcoin']
bit = bit['Close'].to_frame()
bit['timestamp'] = bit['Close'].rolling(30).mean()

bit[['Close', 'timestamp']].plot(label='bit',
                                  figsize=(16, 8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 13
#       8 bit = df2[df2['Asset_Name'] == 'Bitcoin']
#      10 bit['Close'].rolling(30).mean()
#      12 bit[['Close', 'timestamp']].plot(label='bit',
# ---> 13                                   figsize=(16, 8)).rolling(30).mean()
#
# AttributeError: 'Axes' object has no attribute 'rolling'
